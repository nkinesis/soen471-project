# %%
import pandas as pd
import seaborn as sns
import scipy
from scipy.stats import chi2_contingency
from sklearn import tree
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
# define cols to load
part = 100000
selected_cols = ['TFS_Arrival_Time', 'Possible_Cause', 'Property_Use', 
                 'Fire_Alarm_System_Presence', 'Incident_Station_Area',
                'Material_First_Ignited', 'Area_of_Origin']

# load dataset, remove NaN
ds = pd.read_csv('data/Fire-Incidents.csv', usecols=selected_cols)
ds = ds.dropna()
ds = ds[0:part]

# %%
print('Before processing')
print(len(ds))
ds[0:5]
# Out:
# Before processing
# 11214
#                                       Area_of_Origin  \
# 0                                   Porch or Balcony
# 1                            Cooking Area or Kitchen
# 2     Living Area (e.g. living, TV, recreation, etc)
# 3                        Undetermined  (formerly 98)
# 4  Sleeping Area or Bedroom (inc. patients room, ...
#
#   Fire_Alarm_System_Presence  Incident_Station_Area  \
# 0  Fire alarm system present                    114
# 1  Fire alarm system present                    142
# 2  Fire alarm system present                    325
# 3               Undetermined                    332
# 4  Fire alarm system present                    442
#
#        Material_First_Ignited       Possible_Cause  \
# 0  Undetermined (formerly 98)         Undetermined
# 1                     Plastic  Under Investigation
# 2  Undetermined (formerly 98)         Undetermined
# 3  Undetermined (formerly 98)         Undetermined
# 4                     Bedding      Suspected Arson
#
#                           Property_Use     TFS_Arrival_Time
# 0  Multi-Unit Dwelling - Over 12 Units  2018-08-24T16:54:09
# 1                            Infirmary  2018-11-24T07:14:23
# 2  Multi-Unit Dwelling - Over 12 Units  2017-02-09T17:48:49
# 3     Clothing Store, Accessories, fur  2012-10-30T00:44:58
# 4  Multi-Unit Dwelling - Over 12 Units  2018-07-08T04:13:54

# %%
print('Fire_Alarm_System_Presence', ds['Fire_Alarm_System_Presence'].unique())
print('======')
print('Possible_Cause', ds['Area_of_Origin'].unique())
print('======')
print('Property_Use', ds['Property_Use'].unique())
# Out:
# Fire_Alarm_System_Presence ['Fire alarm system present' 'Undetermined' 'No Fire alarm system'
#  'Not applicable (bldg not classified by OBC OR detached/semi/town home)']
# ======
# Possible_Cause ['Porch or Balcony' 'Cooking Area or Kitchen'
#  'Living Area (e.g. living, TV, recreation, etc)'
#  'Undetermined  (formerly 98)'
#  'Sleeping Area or Bedroom (inc. patients room, dormitory, etc)'
#  'Engine Area' 'Concealed Ceiling Area' 'Hallway, Corridor' 'Laundry Area'
#  'Roof' 'Electrical Systems' 'Storage Area (outside)'
#  'Basement/cellar (not partitioned)' 'Court, Patio, Terrace'
#  'Lobby, Entranceway'
#  'Trash, Rubbish Storage (inc garbage chute room, garbage/industri'
#  'Other Outside Area' 'Closet (eg. clothes, broom, linen closet, etc.)'
#  'Garage' 'Trash, rubbish area (outside)'
#  'Dining or Beverage Area (inc mess, canteen, lunchroom, cafeteria'
#  'Washroom or Bathroom (toilet,restroom/locker room)' 'Attached Deck'
#  'Other - unclassified' 'Mechanical/Electrical Services Room'
#  'Other Storage Area' 'Stairway, Escalator' 'Attic Area'
#  'Other Structural Area'
#  'HVAC Equipment Room (furnace room, water heater closet, boiler)'
#  'Office' 'Exterior Wall'
#  'Process Manufacturing (inc manf, prod assembly, repair)'
#  'Chimney/Flue Pipe' 'Sauna' 'Concealed Floor Area'
#  'Ducting - Exhaust (inc cooking, fumes, etc.)'
#  'Supply Storage Room (inc maintenance/office/document storage, et'
#  'Electronic Equipment' 'Sales, Showroom Area' 'Elevator (includes shaft)'
#  'Product Storage (inc products or materials awaiting manuf, assembly)'
#  'Laboratory' 'Fuel Systems (eg. fuel tank, etc.)'
#  'Open Area (inc lawn, field, farmyard, park, playing field, pier,'
#  'Parking Area, Parking Lot' 'Other Functional Area'
#  'Residential/Business: Other busines area' 'Multiple Areas of Origin'
#  'Conveyor Shaft or Chute (inc dumbwaiter, laundry chute, garbage'
#  'Residential/Business: Restaurant area'
#  'Utility Shaft (eg. electrical wiring/phone, etc.)' 'Awning or Canopy'
#  'Concealed Wall Area'
#  'Running Gear (inc wheels and braking systems, transmission syste'
#  'Passenger Area' 'Other Building Services/Support Facilities'
#  'Other Vehicle Area' 'Under Investigation' 'Operator/Control Area'
#  'Locker (apartment storage)' 'Ducting - Heating, Air Conditioning'
#  'Performance Area (inc stage, rink, boxing ring, gym floor, altar'
#  'Shipping/Receiving/Loading Platform'
#  'Crawl Space (includes sub-structure)'
#  'Assembly Area (inc school room,spectator area, church, etc)'
#  'Covered Court, Atrium, mall concourse' 'Other Means of Egress'
#  'Trunk/Cargo Area' 'Operating Room, Treatment or Examination Area'
#  'Incinerator Room' 'Fuel Dispensing Area (outside)'
#  'Records storage area (inc vaults)']
# ======
# Property_Use ['Multi-Unit Dwelling - Over 12 Units' 'Infirmary'
#  'Clothing Store, Accessories, fur' 'Detached Dwelling'
#  'Other care facility' 'Rooming/Boarding/Lodging House'
#  'Semi-Detached Dwelling' 'School - Technical, Industrial Trade'
#  'General Business Office' 'Multi-Unit Dwelling - 2 to 6 Units' 'Bank'
#  'Apartment, Flat, Tenement with Business'
#  'Restaurant (occupant load less than 30 persons)'
#  'Multi-Unit Dwelling - 7 to 12 Units'
#  'Detached/Semi/Attached with Accessory Apartment Below Grade'
#  'Hotel, Motel, Lodging - 4 or more guests or suites' 'Railway Station'
#  'Motor Vehicle Repair Garage'
#  'Gifts, jewellery, leather goods, mixed goods'
#  'Attached Dwelling (eg. rowhouse, townhouse, etc.)' 'Retirement Home'
#  'Halfway/Transitional House' 'Sto: Chemicals, inc hazardous chemicals'
#  'Shelter for displaced/abused persons'
#  'Seniors long term care facility, licensed'
#  'Attached Dwelling with Business' 'Church Hall' 'Library'
#  'Theatre - Concert Hall, Live' 'Sto: Meat/Poultry/Fish products'
#  'Department Store' 'Court Facility' 'Community/Exhibition/Dance Hall'
#  'Restaurants (occupant load greater than 30 persons, licensed)'
#  'School - Secondary/Senior High (Gr. 9+)' 'School - Elementary'
#  'Sports/Country/Social/Yacht Club'
#  'Mfg: Other Chemical/Petroleum/Paint/Plastic Products' 'Auditorium'
#  'Laundry, Dry Cleaner (includes self-service)'
#  'School - Post Secondary (University)'
#  'Residential Club (inc sorority, fraternity)' 'Other Industrial'
#  'Mfg: Pulp, Paper Processing' 'Detached Garage' 'Garden Supply'
#  'Mfg: Chemicals, inc hazardous chemicals'
#  'Exhibition, Fair Stand, Amusement Park Structure'
#  'Sto: Other Vehicles, Parts' 'Garage:  General Auto Parking - Structure'
#  'Convalescent Home or long term care (excluding senior care)'
#  'Mfg: Other Metal/Eletctrical/Miscellaneous Products' 'Museum'
#  'Barber Shop, Hairdresser, Beauty Parlor, tanning salon'
#  'Other Mercantile'
#  'Mfg: Printing, Publishing (eg newspapers, magazines, books)'
#  'Sanitary Services (includes plant)' 'Big Box Store'
#  'Other Business or Personal Services' 'Mfg: Asphalt Products'
#  'School - Post Secondary (College)' 'Arena' 'Subway Station'
#  'Convenience/Variety Store'
#  'Mfg: Secondary Processing (eg finished goods, furniture, etc)'
#  'Dental/Medical Office' 'Group Home' 'Mfg: Grain Products, Bakery Goods'
#  'Supermarket, Grocery Store' 'Detached Dwelling with Business'
#  'Detached/Semi/Attached with Accessory Apartment Above Grade' 'Pharmacy'
#  'Liquor/Wine/Beer Store' 'School - Secondary Junior High (Gr. 7 & 8)'
#  'Houseboat' 'Bar, Tavern, Night Club'
#  'Church, Other Similar Place of Worship'
#  'Mfg: Drugs, Cosmetics, Pharmaceutical' 'Mfg: Road Vehicles, Parts'
#  'Specialty Food Store (eg. butcher, delicatessen, etc.)'
#  'Sto: Other Agri Products, Food, Beverages, Tobacco, etc'
#  'TV, radio, motion picture studio'
#  'Sto: Warehouse, variety of items, not classified by codes'
#  'Other Assembly' 'Recycling Facility'
#  'Mall - public area common to multi store facility'
#  'Theatre - Motion Picture'
#  'Mfg: Secondary Metal Processing (eg rolling, drawing, polishing)'
#  'Public/Private Hospital'
#  'Mfg: Other Wood, Furniture, Paper Products, Printing'
#  'Motor Home, Camper, Trailer' 'Mfg: Meat/Poultry/Fish Products'
#  'Hydro Distribution Facility' 'Jail, Prison, Penitentiary'
#  'Waste Transfer Station' 'Other Residential' 'Mfg: Plastics'
#  'Tent or temporary structure for Mercantile activity'
#  'Computer, electronic data processing, records storage'
#  'Semi-Detached Dwelling with Business' 'Mfg: Alcoholic Beverages'
#  'Bus Terminal' 'Water Works' 'Mfg: Rubber Goods' 'Hospice'
#  'Furniture/Appliance Store' 'Day Care Centre' 'Convent, Monastery'
#  'Tent or temporary structure for assembly activity'
#  'Furniture, upholstery repair without sales' 'Dance Studio'
#  'Other Utilities' 'Casino' 'Laboratory'
#  'Tent or temporary structure for business or personal service activity'
#  'Document centre, record repository (inc archives)' 'Art Gallery'
#  'Mfg: Sugar Refining, Sugar Products'
#  'Mfg: Other Textiles, Clothing, Leather goods' 'Service Station'
#  'Mfg: Watercraft, Parts' 'Mobile Home'
#  'Police Station (without detention quarters)'
#  'Sto: Tent or temporary structure for industrial storage'
#  'Mfg: Other Agr/Food, Beverage, Tabac products'
#  'Psychiatric Hospital (with detention quarters)'
#  'Sto: Other Metal/Electrical/Misc Parts' 'Catalogue/Mail Order Outlet'
#  'Motor Vehicle Sales' 'Gas Distribution Facility'
#  'Sto: Other Chem/Petroleum/Paint/Plastic Products' 'Sto: Textiles'
#  'Sto: Road Vehicles, Parts' 'Mfg: Other Vehicles, Parts'
#  'Sto: Cold Storage - Processed Food' 'Mfg: Petroleum Products' 'Hostel'
#  'Fire Station' 'Stadium' 'Institute for the blind, deaf'
#  'Building Supply Store' 'Indoor Swimming Facility'
#  'Rug, floor covering store'
#  'Small Tool/Appliance Rental/Service Establishment' 'Florist'
#  'Mfg: Primary Metal Processing (eg refining, melting, etc)'
#  'School/College Dormitory (detached from educational facility)'
#  'Mfg: Wearing Apparal Manufacturing' 'Book/Stationary/Art Supply Store'
#  'Mailing, photocopying office' 'Hardware Store' 'Ice Rink'
#  'Sto: Glass & Glass Products, pottery, chinaware' 'Tent'
#  'Mfg: Vegetable/Animal Oil Products' 'Marina, Marine Service Station'
#  'Lecture Hall'
#  'Mfg: Textile Manufacturing (e.g. preparing fibers, spinning, weaving)'
#  'Gymnasium' 'Police Station (with detention quarters)'
#  'Sto: Tank, Tank Farm, Other Liquids' 'Mfg: Precious Metals, Jewellery'
#  'Marine Terminal' 'Specialty Vehicles, Parts' 'Video Rental Shop'
#  'Market - Indoors (flowers, fruit, vegetable sales)'
#  'Sto: Wearing Apparal' 'Structure under 10 sq. metres not classified'
#  'Sto: Other Wood, Furniture, Paper Products, Printing'
#  'Motor Vehicle Parts, Accessory Sales' 'Sto: Plastics'
#  'Secondary Products (eg. finished goods, furniture, etc.)'
#  'Mfg: Aircraft, Parts' 'Other Vehicle Sales/Service'
#  'Bowling Alley, Billiard Centre, pool hall'
#  'Computer/electronics store, service or repair'
#  'Psychiatric Hospital (without detention quarters)'
#  'Mfg: Job Printing (eg forms, greeting cards, etc)' 'Sto: Soft Drinks'
#  'Sto: Rail Vehicles, Parts' 'Bingo Hall' 'Paint/Wallpaper Store'
#  'Mfg:Glass & glass products, china, pottery'
#  'Sto: Grain Products, Bakery Goods' 'Sto: Other Textile Goods'
#  'Hotel, Motel, Lodging - Less than 4 guests or suites (inc B&B)'
#  'Market - Outdoors (flowers, fruit, vegetable sales)' 'Automobile'
#  'Mfg:  Canning, preserving, processing fruits, vegetables'
#  'Sto: Packed food stuffs (not classified by other codes)'
#  'Mfg: Primary Processing (eg sawmill, plywood manufacturer, etc)'
#  'School - Pre-Elementary' 'Sto: Specialty Vehicles, Parts'
#  'Mfg:  Floor covering and coated fabrics (exc rubber, ceramic)'
#  'Mfg: Dry Cleaning Plant' 'Fabric Store' 'Sto: Dairy Goods, Produce'
#  'Sto: Pulp, Paper' 'School - Business, Commerce, Secretarial'
#  'Sto: Vegetable/Animal Oil Products' 'Funeral Facility' 'Lumber Yard'
#  'Adult Detention Camp (minimum security)' 'Non Residential Club'
#  'Other Care & Detention Not Classified' 'Sto: Dry Cleaning Plant'
#  'Bleacher, Grandstand, Reviewing Stand'
#  'Sto: Sugar Refining, Sugar Products' 'Legislative Facility/Building'
#  'Mfg: Prec.Goods/Instruments (eg surgical instr, cameras, etc)'
#  'Mfg: Paint, Varnishes, Lacquers' 'Post Office'
#  'Reformatory (with detention quarters)'
#  'Engineering, Architect or Tech office'
#  'Trash/Rubbish/Garbage Container or Dumpster'
#  'Sto: Precision Goods/Instruments'
#  'Heating Plant - central/district heating plant, steam, etc']

# %%
ds['TFS_Arrival_Time'] = ds['TFS_Arrival_Time'].apply(lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%S').strftime('%-m'))
ds['TFS_Arrival_Time'] = ds['TFS_Arrival_Time'].astype('int')
for col in selected_cols[1:len(selected_cols)]:
    unique_col = ds[col].unique()
    for date in unique_col:
        ds[col] = ds[col].replace(date, np.where(unique_col == date)[0][0])
ds.to_csv('toronto.csv', index=False)

# %%
print('After processing')
print(len(ds))
ds[:5]
# Out:
# After processing
# 11214
#    Area_of_Origin  Fire_Alarm_System_Presence  Incident_Station_Area  \
# 0               0                           0                      0
# 1               1                           0                      1
# 2               2                           0                      2
# 3               3                           1                      3
# 4               4                           0                      4
#
#    Material_First_Ignited  Possible_Cause  Property_Use  TFS_Arrival_Time
# 0                       0               0             0                 8
# 1                       1               1             1                11
# 2                       0               0             0                 2
# 3                       0               0             2                10
# 4                       2               2             0                 7

# %%
# pandas correlation, may not be suitable for categorical
corr = ds.corr(method='kendall', min_periods=1)
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
# chi square correlation, suitable for categorical
# source: https://www.youtube.com/watch?v=_jdfjRzaHMM
tips_categorical=ds[['TFS_Arrival_Time', 'Possible_Cause', 'Property_Use', 
                 'Fire_Alarm_System_Presence', 'Incident_Station_Area',
                'Material_First_Ignited', 'Area_of_Origin']]

def cramers_V(var1,var2):
  crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
  stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
  obs = np.sum(crosstab) # Number of observations
  mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
  return (stat/(obs*mini))

rows= []

for var1 in tips_categorical:
  col = []
  for var2 in tips_categorical :
    cramers =cramers_V(tips_categorical[var1], tips_categorical[var2]) # Cramer's V test
    col.append(round(cramers,2)) # Keeping of the rounded value of the Cramer's V  
  rows.append(col)
  
cramers_results = np.array(rows)
df = pd.DataFrame(cramers_results, columns = tips_categorical.columns, index =tips_categorical.columns)

# %%
df
# Out:
#                             TFS_Arrival_Time  Possible_Cause  Property_Use  \
# TFS_Arrival_Time                        1.00            0.00          0.02
# Possible_Cause                          0.00            1.00          0.03
# Property_Use                            0.02            0.03          1.00
# Fire_Alarm_System_Presence              0.00            0.01          0.21
# Incident_Station_Area                   0.01            0.01          0.04
# Material_First_Ignited                  0.01            0.07          0.03
# Area_of_Origin                          0.01            0.07          0.07
#
#                             Fire_Alarm_System_Presence  Incident_Station_Area  \
# TFS_Arrival_Time                                  0.00                   0.01
# Possible_Cause                                    0.01                   0.01
# Property_Use                                      0.21                   0.04
# Fire_Alarm_System_Presence                        1.00                   0.05
# Incident_Station_Area                             0.05                   1.00
# Material_First_Ignited                            0.03                   0.01
# Area_of_Origin                                    0.06                   0.01
#
#                             Material_First_Ignited  Area_of_Origin
# TFS_Arrival_Time                              0.01            0.01
# Possible_Cause                                0.07            0.07
# Property_Use                                  0.03            0.07
# Fire_Alarm_System_Presence                    0.03            0.06
# Incident_Station_Area                         0.01            0.01
# Material_First_Ignited                        1.00            0.08
# Area_of_Origin                                0.08            1.00

# %%
# generating 2-D 10x10 matrix of random numbers
# from 1 to 100
data = np.random.randint(low=1,
                         high=100,
                         size=(10, 10))
  
# setting the parameter values
annot = True
  
# plotting the heatmap
hm = sns.heatmap(data=df,
                annot=annot)
  
# displaying the plotted heatmap
plt.show()
