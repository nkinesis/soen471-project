# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import scipy
import numpy as np
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Import the data

# %%
df = pd.read_csv('Fire_Department_Calls_for_Service.csv').iloc[:2000 :]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23620/1188421777.py in <module>
# ----> 1 df = pd.read_csv('Fire_Department_Calls_for_Service.csv').iloc[:2000 :]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Fire_Department_Calls_for_Service.csv'

# %%
df.to_csv('fire_department_truncated.csv')

# %%
df.tail()
# Out:
#       Call Number Unit ID  Incident Number         Call Type   Call Date  \
# 1995      1110045     E43            32940    Structure Fire  04/20/2000
# 1996      1110045     T15            32940    Structure Fire  04/20/2000
# 1997      1110048    RA32            32943  Medical Incident  04/20/2000
# 1998      1110049     E01            32944  Medical Incident  04/20/2000
# 1999      1110049     M08            32944  Medical Incident  04/20/2000
#
#       Watch Date           Received DtTm              Entry DtTm  \
# 1995  04/20/2000  04/20/2000 08:09:54 AM  04/20/2000 08:18:07 AM
# 1996  04/20/2000  04/20/2000 08:09:54 AM  04/20/2000 08:18:07 AM
# 1997  04/20/2000  04/20/2000 08:30:24 AM  04/20/2000 08:32:16 AM
# 1998  04/20/2000  04/20/2000 08:34:43 AM  04/20/2000 08:36:08 AM
# 1999  04/20/2000  04/20/2000 08:34:43 AM  04/20/2000 08:36:08 AM
#
#                Dispatch DtTm           Response DtTm  ... ALS Unit  \
# 1995  04/20/2000 08:18:18 AM  04/20/2000 08:19:21 AM  ...    False
# 1996  04/20/2000 08:18:18 AM  04/20/2000 08:19:21 AM  ...    False
# 1997  04/20/2000 08:33:06 AM  04/20/2000 08:33:41 AM  ...    False
# 1998  04/20/2000 08:36:37 AM  04/20/2000 08:39:17 AM  ...    False
# 1999  04/20/2000 08:36:37 AM  04/20/2000 08:38:29 AM  ...     True
#
#      Call Type Group Number of Alarms Unit Type  \
# 1995             NaN                1    ENGINE
# 1996             NaN                1     TRUCK
# 1997             NaN                1   AIRPORT
# 1998             NaN                1    ENGINE
# 1999             NaN                1     MEDIC
#
#      Unit sequence in call dispatch Fire Prevention District  \
# 1995                            1.0                        9
# 1996                            2.0                        9
# 1997                            1.0                       10
# 1998                            1.0                        3
# 1999                            2.0                        3
#
#      Supervisor District  Neighborhooods - Analysis Boundaries  \
# 1995                  11                             Excelsior
# 1996                  11                             Excelsior
# 1997                  10                          Potrero Hill
# 1998                   6                       South of Market
# 1999                   6                       South of Market
#
#                                    Location           RowID
# 1995  (37.7247251220887, -122.430453102329)   001110045-E43
# 1996  (37.7247251220887, -122.430453102329)   001110045-T15
# 1997  (37.7536098398255, -122.397099082289)  001110048-RA32
# 1998  (37.7773283973146, -122.407203031938)   001110049-E01
# 1999  (37.7773283973146, -122.407203031938)   001110049-M08
#
# [5 rows x 34 columns]

# %% [markdown]
# ##### drop any empty cells

# %%
columns_to_drop = ["Call Number", "Incident Number", "Call Type Group", "RowID", "Call Date", "Hospital DtTm", "Call Final Disposition", "Available DtTm", "Address"]
rows_to_keep = ["Structure Fire"]

# %%
df = df.drop(columns_to_drop, axis=1)

# %%
df
# Out:
#      Unit ID         Call Type  Watch Date           Received DtTm  \
# 0        E18  Medical Incident  04/12/2000  04/12/2000 09:00:29 PM
# 1        M14  Medical Incident  04/12/2000  04/12/2000 09:09:02 PM
# 2        M36  Medical Incident  04/12/2000  04/12/2000 09:09:44 PM
# 3        E01            Alarms  04/12/2000  04/12/2000 09:13:47 PM
# 4        RS1  Medical Incident  04/12/2000  04/12/2000 09:14:43 PM
# ...      ...               ...         ...                     ...
# 1995     E43    Structure Fire  04/20/2000  04/20/2000 08:09:54 AM
# 1996     T15    Structure Fire  04/20/2000  04/20/2000 08:09:54 AM
# 1997    RA32  Medical Incident  04/20/2000  04/20/2000 08:30:24 AM
# 1998     E01  Medical Incident  04/20/2000  04/20/2000 08:34:43 AM
# 1999     M08  Medical Incident  04/20/2000  04/20/2000 08:34:43 AM
#
#                   Entry DtTm           Dispatch DtTm           Response DtTm  \
# 0     04/12/2000 09:01:40 PM  04/12/2000 09:02:00 PM                     NaN
# 1     04/12/2000 09:10:17 PM  04/12/2000 09:10:29 PM  04/12/2000 09:12:11 PM
# 2     04/12/2000 09:10:56 PM  04/12/2000 09:11:47 PM                     NaN
# 3     04/12/2000 09:13:51 PM  04/12/2000 09:14:13 PM  04/12/2000 09:15:58 PM
# 4     04/12/2000 09:16:11 PM  04/12/2000 09:16:24 PM  04/12/2000 09:18:20 PM
# ...                      ...                     ...                     ...
# 1995  04/20/2000 08:18:07 AM  04/20/2000 08:18:18 AM  04/20/2000 08:19:21 AM
# 1996  04/20/2000 08:18:07 AM  04/20/2000 08:18:18 AM  04/20/2000 08:19:21 AM
# 1997  04/20/2000 08:32:16 AM  04/20/2000 08:33:06 AM  04/20/2000 08:33:41 AM
# 1998  04/20/2000 08:36:08 AM  04/20/2000 08:36:37 AM  04/20/2000 08:39:17 AM
# 1999  04/20/2000 08:36:08 AM  04/20/2000 08:36:37 AM  04/20/2000 08:38:29 AM
#
#                On Scene DtTm          Transport DtTm City  ...  Priority  \
# 0                        NaN                     NaN   SF  ...         3
# 1     04/12/2000 09:19:36 PM  04/12/2000 09:43:57 PM   SF  ...         3
# 2     04/12/2000 09:14:11 PM  04/12/2000 09:59:31 PM   SF  ...         3
# 3     04/12/2000 09:20:12 PM                     NaN   SF  ...         3
# 4     04/12/2000 09:20:08 PM                     NaN   SF  ...         3
# ...                      ...                     ...  ...  ...       ...
# 1995  04/20/2000 08:21:44 AM                     NaN   SF  ...         3
# 1996                     NaN                     NaN   SF  ...         3
# 1997  04/20/2000 08:46:58 AM  04/20/2000 09:03:02 AM   SF  ...         1
# 1998  04/20/2000 08:39:43 AM                     NaN   SF  ...         3
# 1999  04/20/2000 08:42:03 AM                     NaN   SF  ...         3
#
#      Final Priority ALS Unit Number of Alarms     Unit Type  \
# 0                 3    False                1        ENGINE
# 1                 3     True                1         MEDIC
# 2                 3    False                1         MEDIC
# 3                 3    False                1        ENGINE
# 4                 3    False                1  RESCUE SQUAD
# ...             ...      ...              ...           ...
# 1995              3    False                1        ENGINE
# 1996              3    False                1         TRUCK
# 1997              2    False                1       AIRPORT
# 1998              3    False                1        ENGINE
# 1999              3     True                1         MEDIC
#
#      Unit sequence in call dispatch  Fire Prevention District  \
# 0                               1.0                         8
# 1                               2.0                         8
# 2                               1.0                         2
# 3                               3.0                         3
# 4                               2.0                         1
# ...                             ...                       ...
# 1995                            1.0                         9
# 1996                            2.0                         9
# 1997                            1.0                        10
# 1998                            1.0                         3
# 1999                            2.0                         3
#
#       Supervisor District  Neighborhooods - Analysis Boundaries  \
# 0                       4                       Sunset/Parkside
# 1                       4                       Sunset/Parkside
# 2                       6                            Tenderloin
# 3                       6                            Tenderloin
# 4                       3        Financial District/South Beach
# ...                   ...                                   ...
# 1995                   11                             Excelsior
# 1996                   11                             Excelsior
# 1997                   10                          Potrero Hill
# 1998                    6                       South of Market
# 1999                    6                       South of Market
#
#                                    Location
# 0     (37.7487247711275, -122.495504020186)
# 1     (37.7540326780595, -122.502185504543)
# 2     (37.7764405100838, -122.418481123408)
# 3     (37.7825474000421, -122.412247935495)
# 4     (37.7863072236365, -122.405294845215)
# ...                                     ...
# 1995  (37.7247251220887, -122.430453102329)
# 1996  (37.7247251220887, -122.430453102329)
# 1997  (37.7536098398255, -122.397099082289)
# 1998  (37.7773283973146, -122.407203031938)
# 1999  (37.7773283973146, -122.407203031938)
#
# [2000 rows x 25 columns]

# %%
df = df.loc[df["Call Type"].isin(rows_to_keep)]

# %%
df

# %%
df.to_csv("fire_incidents_sanfran.csv")

# %%
corr = df.corr(method='kendall', min_periods=1)
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True)
# Out:
# C:\Users\rhani\AppData\Local\Temp\ipykernel_14272\569657107.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method='kendall', min_periods=1)
# <AxesSubplot: >

# %%
df
