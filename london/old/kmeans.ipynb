# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# define cols to load
part = 100000
ds = pd.read_csv('out.csv')
ds = ds.dropna()
ds = ds[0:part]

X_train = ds[0:50000].values
X_test = ds[50000:part].values

# %%
X_train[0:10]
# Out:
# array([[  0.,   0.,   0., 319.],
#        [  0.,   1.,   1., 308.],
#        [  0.,   1.,   2., 210.],
#        [  0.,   1.,   3., 233.],
#        [  0.,   2.,   4., 172.],
#        [  0.,   0.,   0., 522.],
#        [  0.,   1.,   5., 342.],
#        [  0.,   1.,   6., 255.],
#        [  0.,   2.,   7., 297.],
#        [  0.,   0.,   8., 256.]])

# %%
labels = kmeans.fit_predict(X_train)

# %%
labels[0:10]
# Out:
# array([2, 2, 1, 1, 1, 4, 2, 2, 2, 2], dtype=int32)

# %%
#Getting unique labels
u_labels = np.unique(labels)
 
#plotting the results:
 
for i in u_labels:
    plt.scatter(X_train[labels == i , 2], X_train[labels == i , 3], label = i)
plt.legend()
plt.show()
