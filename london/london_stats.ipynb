# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot

# %%
# define cols to load
desired_cols = ['DateOfCall','TimeOfCall','IncidentGroup','StopCodeDescription', 'PropertyCategory', 
                'PropertyType', 'Notional Cost (£)', 'NumCalls']

# load dataset
# manually checked: there are no NaN DateOfCall
ds = pd.read_csv('data/lfb_incident.csv', usecols = desired_cols)
ds
# Out:
#           DateOfCall TimeOfCall    IncidentGroup        StopCodeDescription  \
# 0        01 Jan 2009   00:00:37  Special Service            Special Service
# 1        01 Jan 2009   00:00:46  Special Service            Special Service
# 2        01 Jan 2009   00:03:00             Fire             Secondary Fire
# 3        01 Jan 2009   00:04:27             Fire             Secondary Fire
# 4        01 Jan 2009   00:05:39             Fire             Secondary Fire
# ...              ...        ...              ...                        ...
# 1465055  30 Jun 2022   23:42:53      False Alarm                        AFA
# 1465056  30 Jun 2022   23:46:26  Special Service            Special Service
# 1465057  30 Jun 2022   23:46:44      False Alarm                        AFA
# 1465058  30 Jun 2022   23:47:55      False Alarm  False alarm - Good intent
# 1465059  30 Jun 2022   23:48:37  Special Service            Special Service
#
# ...

# %%
for col_name in desired_cols:
    print(ds[col_name].value_counts())
    print("=========================")
# Out:
# 12 Jul 2021    1058
# 25 Jul 2021    1043
# 23 Jun 2016     998
# 18 Feb 2022     860
# 03 Mar 2018     835
#                ...
# 12 Jun 2014      99
# 09 Dec 2014      96
# 02 Nov 2014      67
# 01 Nov 2014      48
# 03 Nov 2014      40
# Name: DateOfCall, Length: 4929, dtype: int64
# ...
# 19:11:16    48
# 18:02:06    44
# 18:53:39    44
# 17:12:19    44
# 18:12:47    43
#             ..
# 03:32:46     1
# 05:51:53     1
# 05:17:30     1
# 05:13:29     1
# 03:40:22     1
# Name: TimeOfCall, Length: 86385, dtype: int64
# ...
# False Alarm        719775
# Special Service    459264
# Fire               286021
# Name: IncidentGroup, dtype: int64
# ...
# AFA                                      538675
# Special Service                          456160
# False alarm - Good intent                160585
# Primary Fire                             147487
# Secondary Fire                           137771
# False alarm - Malicious                   20515
# Flood call attended - Batch mobilised      3044
# ...
